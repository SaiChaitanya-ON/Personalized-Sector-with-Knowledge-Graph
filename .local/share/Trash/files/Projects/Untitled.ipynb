# %%
! pip install numpy
# Out:
# Looking in indexes: https://aws:****@oaknorth-264571470104.d.codeartifact.eu-west-1.amazonaws.com/pypi/python/simple/
# Collecting numpy
#   Downloading https://oaknorth-264571470104.d.codeartifact.eu-west-1.amazonaws.com/pypi/python/simple/numpy/1.20.3/numpy-1.20.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.4 MB)
#      |████████████████████████████████| 15.4 MB 252 kB/s eta 0:00:01    |█                               | 450 kB 288 kB/s eta 0:00:52     |██▎                             | 1.1 MB 245 kB/s eta 0:00:59     |███                             | 1.4 MB 245 kB/s eta 0:00:57     |███▌                            | 1.7 MB 258 kB/s eta 0:00:54     |████▏                           | 2.0 MB 263 kB/s eta 0:00:51     |█████▊                          | 2.7 MB 250 kB/s eta 0:00:51     |██████▏                         | 3.0 MB 355 kB/s eta 0:00:35     |███████▌                        | 3.6 MB 165 kB/s eta 0:01:11     |████████▌                       | 4.1 MB 245 kB/s eta 0:00:46     |███████████▏                    | 5.3 MB 249 kB/s eta 0:00:41     |████████████                    | 5.7 MB 256 kB/s eta 0:00:38     |█████████████▏                  | 6.3 MB 220 kB/s eta 0:00:41     |██████████████                  | 6.7 MB 267 kB/s eta 0:00:33     |███████████████▋                | 7.5 MB 252 kB/s eta 0:00:32     |████████████████▍               | 7.9 MB 252 kB/s eta 0:00:30     |████████████████████▏           | 9.7 MB 287 kB/s eta 0:00:20     |████████████████████▌           | 9.8 MB 287 kB/s eta 0:00:20     |██████████████████████▍         | 10.8 MB 251 kB/s eta 0:00:19     |███████████████████████▎        | 11.2 MB 508 kB/s eta 0:00:09     |████████████████████████        | 11.5 MB 250 kB/s eta 0:00:16     |████████████████████████▌       | 11.8 MB 250 kB/s eta 0:00:15     |██████████████████████████▏     | 12.6 MB 249 kB/s eta 0:00:12     |███████████████████████████▏    | 13.1 MB 245 kB/s eta 0:00:10     |████████████████████████████▌   | 13.7 MB 307 kB/s eta 0:00:06     |█████████████████████████████▎  | 14.1 MB 283 kB/s eta 0:00:05     |██████████████████████████████▎ | 14.5 MB 251 kB/s eta 0:00:04
# Installing collected packages: numpy
# Successfully installed numpy-1.20.3

# %%
! pip install SQLAlchemy
# Out:
# Looking in indexes: https://aws:****@oaknorth-264571470104.d.codeartifact.eu-west-1.amazonaws.com/pypi/python/simple/
# Collecting SQLAlchemy
#   Downloading https://oaknorth-264571470104.d.codeartifact.eu-west-1.amazonaws.com/pypi/python/simple/sqlalchemy/1.4.18/SQLAlchemy-1.4.18-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 201 kB/s eta 0:00:01     |█                               | 51 kB 348 kB/s eta 0:00:05     |████                            | 194 kB 692 kB/s eta 0:00:02     |█████████████████████▎          | 1.0 MB 253 kB/s eta 0:00:03
# Collecting greenlet!=0.4.17
#   Downloading https://oaknorth-264571470104.d.codeartifact.eu-west-1.amazonaws.com/pypi/python/simple/greenlet/1.1.0/greenlet-1.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#      |████████████████████████████████| 164 kB 699 kB/s eta 0:00:01
# Installing collected packages: greenlet, SQLAlchemy
# Successfully installed SQLAlchemy-1.4.18 greenlet-1.1.0

# %%
! pip install psycopg2-binary
# Out:
# Looking in indexes: https://aws:****@oaknorth-264571470104.d.codeartifact.eu-west-1.amazonaws.com/pypi/python/simple/
# Collecting psycopg2-binary
#   Downloading https://oaknorth-264571470104.d.codeartifact.eu-west-1.amazonaws.com/pypi/python/simple/psycopg2-binary/2.8.6/psycopg2_binary-2.8.6-cp38-cp38-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 351 kB/s eta 0:00:01     |▏                               | 20 kB 138 kB/s eta 0:00:22     |███████████▍                    | 1.1 MB 503 kB/s eta 0:00:04     |██████████████████▍             | 1.7 MB 252 kB/s eta 0:00:06     |██████████████████████          | 2.0 MB 252 kB/s eta 0:00:04
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.8.6

# %%
import numpy as np

# %%
from sqlalchemy import text
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from uuid import uuid4,UUID

UNDERWRITER_URL = 'postgresql://root:test_pw@localhost:5432/underwriting'

# %%
engine = create_engine(UNDERWRITER_URL, pool_pre_ping=True)
print("A")
with engine.connect() as conn:
    print("B")
    result = conn.execute("select * from loan limit 20")
    for row in result:
        print(row)
# Out:
# A
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3210         try:
# -> 3211             return fn()
#    3212         except dialect.dbapi.Error as e:
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-73ea4ebc32cc> in <module>
#       1 engine = create_engine(UNDERWRITER_URL, pool_pre_ping=True)
#       2 print("A")
# ----> 3 with engine.connect() as conn:
#       4     print("B")
#       5     result = conn.execute("select * from loan limit 20")
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3163         """
#    3164
# -> 3165         return self._connection_cls(self, close_with_result=close_with_result)
#    3166
#    3167     @util.deprecated(
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3242
#    3243         """
# -> 3244         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3245
#    3246
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3212         except dialect.dbapi.Error as e:
#    3213             if connection is None:
# -> 3214                 Connection._handle_dbapi_exception_noconnection(
#    3215                     e, dialect, self
#    3216                 )
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2066             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2067         elif should_wrap:
# -> 2068             util.raise_(
#    2069                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2070             )
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3209         dialect = self.dialect
#    3210         try:
# -> 3211             return fn()
#    3212         except dialect.dbapi.Error as e:
#    3213             if connection is None:
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     305
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#     309     def _return_conn(self, record):
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     765     def _checkout(cls, pool, threadconns=None, fairy=None):
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#     769             fairy._pool = pool
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     423     @classmethod
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#     427             dbapi_connection = rec.get_connection()
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     251         """Called by subclasses to create a new ConnectionRecord."""
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#     255     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     366         self.__pool = pool
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#     370
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     609         except Exception as e:
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#     613             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     603         try:
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#     607             self.connection = connection
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# ~/Jupyter_dir/Project_env/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
