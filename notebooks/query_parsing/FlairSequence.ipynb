# %%
from flair.models import SequenceTagger

from flair.data import Sentence

import graphene
from elasticsearch import Elasticsearch
from elasticsearch.helpers import scan
from elasticsearch_dsl import Q, Search
import numpy as np
import pickle
import string
import sys
import timeit

from itertools import islice
from collections import deque, defaultdict, Counter

from nltk import ChartParser
from nltk.parse.generate import generate
from nltk.grammar import CFG, Nonterminal
from nltk.tree import Tree
from semantic.numbers import NumberService

HOST = "http://18.203.139.101:9200"
INDEX = "company"

client = Elasticsearch(HOST+"/")

# %% [markdown]
# ## TODO:
# * implement fallback search that just concats all fields and looks for query terms in there
# * implement range queries
# * huge stretch: implement logical functionality (and/or/not)

# %% [markdown]
# ### Load Word Counts

# %% [markdown]
# ### Use the above field values to make a simple query-parsing grammer

# %%
number_parser = NumberService()

ner_tagger = SequenceTagger.load('ner-ontonotes-fast')
pos_tagger = SequenceTagger.load("pos-fast")

comparator_expressions = {
        "gte": ["greater than or equal to", "minimum", "min", "at least", "not less than", "not fewer than", ">=",
                "no less than", "no fewer than"
               ],
        "gt": ["greater than", "more than", ">", "above", "over"],
        "lte": ["less than or equal to", "maximum", "max", "at most", "not greater than", "not more than", "<=",
                "no more than"
               ],
        "lt": ["less than", "fewer than", "<", "below", "under"]
    }

reverse_comparator_expressions = {v:k for k,vs in comparator_expressions.items() for v in vs}

with open("company_grammar.pkl", 'rb') as f:
    company_grammar = pickle.load(f)
# Out:
# 2019-07-15 17:55:55,477 loading file /Users/andrei-alinpopescu/.flair/models/en-ner-ontonotes-fast-v0.3.pt
# 2019-07-15 17:56:04,510 loading file /Users/andrei-alinpopescu/.flair/models/en-pos-ontonotes-fast-v0.2.pt

# %%
def replace_tags(original_sentence, tagged_sentence, tagger_type, tags_to_replace = None):
    ''' Replace natural language sequence with its found tag
    :param original_sentence: str
    :param tagged_sentence: flair Sentence object that as been tagged by a Tagger
    :param tagger_type: str which tagger has been used 'ner' or 'pos'
    :param tags_to_replace: List[str] which tags found by Tagger to replace. If None, replace all tags
    
    :return : Tuple[str, Dict[str, deque[str]]] returns the sentence with tags replaced and the original values that
              the tags had in the text. This latter return is used when parsing the syntax tree to re-populate the
              initial textual values. Processing them in a FIFO manner ensures consistency when doing this (so initial
              values get mapped to the correct syntax tree leaves)
    '''

    tags = {}

    tagged_string = ""
    prev_end = 0
    
    print(tagged_sentence.to_dict(tagger_type)['entities'])
    
    for entity in tagged_sentence.to_dict(tagger_type)['entities']:
        start_pos = entity['start_pos']
        end_pos   = entity['end_pos']
        tag_type = f"<{entity['type'].lower()}>"
        if tags_to_replace is not None and tag_type not in tags_to_replace:
            continue
        if tag_type not in tags:
            tags[tag_type] = deque()
        tags[tag_type].append(original_sentence[start_pos:end_pos])

        tagged_string += original_sentence[prev_end:start_pos]
        tagged_string += tag_type
        prev_end = end_pos
    tagged_string += original_sentence[prev_end:]

    return tagged_string, tags


def preprocess_sentence(original_sentence):
    ''' Preprocess a free text query to something our grammar can handle. This works as follows:
        * do POS tagging on the initial sequence, replacing all found cardinals (this is because NER seems to have
          some strange assumptions around what a cardinal is)
        * from the above result, replace comparators with a canonical representation (e.g. 'fewer than' -> '<')
        * remove uninformative words such as interjections and conjunctions
        * do NER tagging to identify countries and regions
    
    :param : str the original sentence
    
    :return : Tuple[str, Dict[str, deque[str]]], return the tag-replaced sentence together with the actual initial tag values
    '''

    sentence = Sentence(original_sentence)
    pos_tagger.predict(sentence)
    pos_sentence, ca_tags = replace_tags(original_sentence, 
                                         sentence, 
                                         tagger_type="pos", 
                                         tags_to_replace=["<cd>"]
                                        )

    if '<cd>' in ca_tags:
        ca_tags['<cardinal>'] = ca_tags['<cd>']
        del ca_tags['<cd>']
        
    print(sentence.to_tagged_string())

    pos_sentence = pos_sentence.replace("<cd>", "<cardinal>")
    
    for matcher, comparator in sorted(reverse_comparator_expressions.items(), key=lambda a: -len(a[0])):
        pos_sentence = pos_sentence.replace(matcher +" <cardinal>", comparator+" <cardinal>")
    
    pos_sentence = pos_sentence.replace("between <cardinal> and <cardinal>", 
                                        "<range_start> <cardinal> <range_end> <cardinal>"
                                       )
        
    sentence = Sentence(pos_sentence)
    pos_tagger.predict(sentence)
    pos_sentence,_ = replace_tags(pos_sentence,
                                  sentence,
                                  tagger_type="pos",
                                  tags_to_replace=["<in>", "<cc>", "<vbg>", "<dt>"]
                                 )

    pos_sentence = pos_sentence.replace("<in>", "").replace("<cc>", "").replace("<vbg>", "").replace("<dt>", "")
    
    sentence = Sentence(pos_sentence)
    ner_tagger.predict(sentence)

    ner_sentence, ner_tags = replace_tags(pos_sentence, 
                                          sentence, 
                                          tagger_type="ner",
                                          tags_to_replace=["<gpe>", "<loc>"]
                                         )
    ner_tags.update(ca_tags)

    return ner_sentence, ner_tags

# %%
def _process_parse_tree(tree, tags):
    ''' Given a syntax tree and a mapping from tags to initial value, process the syntax tree in a DFS fashion to
        populate the with the original comparison values.
        
        Because all syntax trees have the same leaf order regardless of their actual structure, and because DFS
        traversal retrieves this order, we can safely populate the initial values in the order in which they are
        encountered in this traversal by popping from the appropriate tags queue. E.g. when we encounter a 'cardinal'
        leaf it is always safe to pop the first value in the tags['cardinal'] queue and label the respective 
        leaf with that value.
    '''
    
    ret = {}
    tag_terminals={"<cardinal>", "<gpe>", "<loc>", "<money>"}
    redundant_terminals={"employees", "revenue"}
    def dfs_label(root=tree):
        if isinstance(root, str):
            if root in tag_terminals:
                return tags[root].popleft()
            if root not in redundant_terminals:
                return root
            else:
                return None

        new_children = []
        for el in root:
            labelled_child = dfs_label(el)
            if labelled_child is not None:
                new_children.append(labelled_child)
        return Tree(root.label(), new_children)

    tree = dfs_label()
    return tree

def _populate_query(tree):
    ''' Given a labelled parse tree (i.e. with tags replaces with their original values), attempt to
        generate a mapping of the form field -> condition, which can be used to create an ES querystring
    '''
    ret = {}

    def process_range_subtree(root):
        return [
         ("gte",number_parser.parse(root[1])),
         ("lte",number_parser.parse(root[3]))
        ]
    
    def process_comparator_subtree(root):
        co, ca = None, None
        for child in root:
            if isinstance(child, Tree) and child.label() == 'Ineq':
                co = child[0]
            else:
                ca = child
        return [(co, number_parser.parse(ca))]
        
    def process_numerical_field_subtree(root):
        for child in root:
            if isinstance(child, Tree) and child.label() == 'CO':
                return process_comparator_subtree(child)
            if isinstance(child, Tree) and child.label() == 'Range':
                return process_range_subtree(child)
    
    def process_companytype_subtree(root):
        if isinstance(root, Tree):
            for child in root:
                for kw in process_companytype_subtree(child):
                    yield kw
        else:
            yield root

    def dfs_query_parser(root=tree):
        for child in root:
            if child.label() == 'Link':
                continue
            if child.label() == 'L':
                # TODO: parse L so we distinguish between various location-type queries
                continue
            if child.label() == 'CT':
                company_freetext = " ".join([el for el in process_companytype_subtree(child)])
                ret['industry_class_code_desc'] = company_freetext
                ret['company_description'] = company_freetext
            elif child.label() == 'REGION':
                if 'region' in ret:
                    raise ValueError("Can only have one region identifier")
                ret['region'] = list(child)[0]
            elif child.label() == 'COUNTRY':
                if 'country' in ret:
                    raise ValueError("Can only have one country identifier")
                ret['country'] = list(child)[0]
            elif child.label() == 'EMP':
                if 'number_of_employees' not in ret:
                    ret['number_of_employees'] = []
                ret['number_of_employees'].extend(process_numerical_field_subtree(child))
            elif child.label() == 'REV':
                if 'latest_revenue' not in ret:
                    ret['latest_revenue'] = []
                ret['latest_revenue'].extend(process_numerical_field_subtree(child))
            else:
                dfs_query_parser(child)

    dfs_query_parser()
    return ret

def _build_query_string(parse_dict):
    ''' Given a parse dictionary, produce an ES query string.
    '''
    ret = []
    free_text_company = []
    for field, parse_value in parse_dict.items():
        if field == 'latest_revenue' or field == 'number_of_employees':
            ret.append(f"{field}:({' AND '.join([''.join(co_ca) for co_ca in parse_value])})")
        elif field == 'company_description' or field == 'industry_class_code_desc':
            free_text_company.append("{}:({})".format(field, parse_value))
        else:
            ret.append("{}:({})".format(field, parse_value))
    
    ret.append("("+" OR ".join(free_text_company)+")")
    
    return " AND ".join(ret)

def _fallback_search(input_query, size=10):
    ''' Fall back on this in case nice query processing fails.
    '''
    print("Falling back on free text search")
    s = (Search()
         .using(client)
         .query(
             "query_string",
             fields=["country.keyword", "industry_class_code_desc", "company_description", "region"],
             type="cross_fields",
             query=input_query,
             fuzzy_prefix_length=3
         )
    )
    return s[:size]

def free_text_query(input_query, size=10):
    # N.B flair taggers are the execution bottleneck at the moment
    tagged_sentence, tags = preprocess_sentence(input_query)
    tagged_sentence = tagged_sentence.lower()
    
    parser = ChartParser(company_grammar)
    grammar_tree = None
    try:
        for tree in parser.parse(tagged_sentence.split()):
            grammar_tree = tree
    except Exception as e:
        print("Failed to parse grammar", e)
        return _fallback_search(input_query, size)
        
    if grammar_tree is None:
        print("No found grammar trees")
        return _fallback_search(input_query, size)

    processed_parse_tree = _process_parse_tree(grammar_tree, tags)
    parse_dict = _populate_query(processed_parse_tree)
    
    s = Search(index=INDEX).using(client)
    
    if "region" in parse_dict:
        s=s.query("match", region=parse_dict["region"])
        
    
    s=s.query("multi_match",
             fields = ["company_description", "industry_class_code_desc"],
             query=parse_dict["industry_class_code_desc"],
            )

    
    if "number_of_employees" in parse_dict:
        s=s.filter("range", number_of_employees=dict(parse_dict["number_of_employees"]))
    if "latest_revenue" in parse_dict:
        s=s.filter("range", latest_revenue=dict(parse_dict["latest_revenue"]))
    if "country" in parse_dict:
        s=s.filter({"terms": {"country.keyword": [parse_dict["country"]]}})

    print(s.to_dict())
    print()
    
    if s.count() == 0:
        print("Empty Results")
        return _fallback_search(input_query, size)
    return s[:size]

# %%
input_query = "drug stores in Europe with more than 55 employees and revenue less than 5"

# %%
for hit in free_text_query(input_query, size=100):
    print("score: ", hit.meta['score'])
    print("Name: ", hit.company_name)
    print("Company id: ", hit.company_id)
    print("Country: ", hit.country if hasattr(hit, "country") else "Empty")
    print("Revenue: ", hit.latest_revenue if hasattr(hit, "latest_revenue") else "Empty")
    print("Number of employees: ", hit.number_of_employees if hasattr(hit, "number_of_employees") else "Empty")
    print("Industry :", hit.industry_class_code_desc if hasattr(hit, "industry_class_code_desc") else "Empty")
    print("Company description: ", hit.company_description if hasattr(hit, "company_description") else "Empty")
    print("#"*100)
# Out:
# [{'text': 'drug', 'start_pos': 0, 'end_pos': 4, 'type': 'NN', 'confidence': 0.9994885921478271}, {'text': 'stores', 'start_pos': 5, 'end_pos': 11, 'type': 'NNS', 'confidence': 0.9993044137954712}, {'text': 'in', 'start_pos': 12, 'end_pos': 14, 'type': 'IN', 'confidence': 0.9999935626983643}, {'text': 'Europe', 'start_pos': 15, 'end_pos': 21, 'type': 'NNP', 'confidence': 0.9996509552001953}, {'text': 'with', 'start_pos': 22, 'end_pos': 26, 'type': 'IN', 'confidence': 0.9999909400939941}, {'text': 'more', 'start_pos': 27, 'end_pos': 31, 'type': 'JJR', 'confidence': 0.9984748959541321}, {'text': 'than', 'start_pos': 32, 'end_pos': 36, 'type': 'IN', 'confidence': 0.9999995231628418}, {'text': '55', 'start_pos': 37, 'end_pos': 39, 'type': 'CD', 'confidence': 0.9999997615814209}, {'text': 'employees', 'start_pos': 40, 'end_pos': 49, 'type': 'NNS', 'confidence': 0.9994364380836487}, {'text': 'and', 'start_pos': 50, 'end_pos': 53, 'type': 'CC', 'confidence': 1.0}, {'text': 'revenue', 'start_pos': 54, 'end_pos': 61, 'type': 'NN', 'confidence': 0.9989193677902222}, {'text': 'less', 'start_pos': 62, 'end_pos': 66, 'type': 'JJR', 'confidence': 0.9326505661010742}, {'text': 'than', 'start_pos': 67, 'end_pos': 71, 'type': 'IN', 'confidence': 0.9999957084655762}, {'text': '5', 'start_pos': 72, 'end_pos': 73, 'type': 'CD', 'confidence': 0.9999657869338989}]
# drug <NN> stores <NNS> in <IN> Europe <NNP> with <IN> more <JJR> than <IN> 55 <CD> employees <NNS> and <CC> revenue <NN> less <JJR> than <IN> 5 <CD>
# [{'text': 'drug', 'start_pos': 0, 'end_pos': 4, 'type': 'NN', 'confidence': 0.9994454979896545}, {'text': 'stores', 'start_pos': 5, 'end_pos': 11, 'type': 'NNS', 'confidence': 0.9990003705024719}, {'text': 'in', 'start_pos': 12, 'end_pos': 14, 'type': 'IN', 'confidence': 0.999993085861206}, {'text': 'Europe', 'start_pos': 15, 'end_pos': 21, 'type': 'NNP', 'confidence': 0.9975106716156006}, {'text': 'with', 'start_pos': 22, 'end_pos': 26, 'type': 'IN', 'confidence': 0.9997454285621643}, {'text': 'gt', 'start_pos': 27, 'end_pos': 29, 'type': 'NN', 'confidence': 0.9231016635894775}, {'text': '<cardinal>', 'start_pos': 30, 'end_pos': 40, 'type': 'NNP', 'confidence': 0.6328371167182922}, {'text': 'employees', 'start_pos': 41, 'end_pos': 50, 'type': 'NNS', 'confidence': 0.999442994594574}, {'text': 'and', 'start_pos': 51, 'end_pos': 54, 'type': 'CC', 'confidence': 1.0}, {'text': 'revenue', 'start_pos': 55, 'end_pos': 62, 'type': 'NN', 'confidence': 0.9990471005439758}, {'text': 'lt', 'start_pos': 63, 'end_pos': 65, 'type': 'FW', 'confidence': 0.6237120032310486}, {'text': '<cardinal>', 'start_pos': 66, 'end_pos': 76, 'type': 'NNP', 'confidence': 0.48397377133369446}]
# [{'text': 'Europe', 'start_pos': 13, 'end_pos': 19, 'type': 'LOC', 'confidence': 0.9922864437103271}]
# {'query': {'bool': {'must': [{'match': {'region': 'Europe'}}, {'multi_match': {'fields': ['company_description', 'industry_class_code_desc'], 'query': 'drug stores'}}], 'filter': [{'range': {'number_of_employees': {'gt': 55.0}}}, {'range': {'latest_revenue': {'lt': 5.0}}}]}}}
#
# score:  9.638157
# Name:  Care 4U Pharmacy Ltd
# Company id:  194937038
# Country:  United Kingdom
# Revenue:  3.929008105076072
# Number of employees:  57
# Industry : Drug stores and proprietary stores
# Company description:  Care 4U Pharmacy Ltd. owns and operates pharmacies in South Devon that provides prescription collection and delivery services. The company also provides pharmacy services, such as care home, Community MDS, electronic prescriptions, emergency hormonal contraception, medicine use reviews, needle exchange, medicine advice, NHS flu vaccinations, repeat dispensing, smoking cessation, and supervised consumption. In addition, it offers health advice on conditions, embarrassing problems, family health, healthier living, seniors, smoking cessation, support groups, and travel health. The company was incorporated in 2000 and is based in Paignton, United Kingdom. As of February 27, 2015, Care 4U Pharmacy Ltd operates as a subsidiary of Bestway National Chemists Ltd.
# ####################################################################################################
# score:  6.675524
# Name:  Street 71 Spa
# Company id:  317309696
# Country:  Italy
# Revenue:  3.760520704746942
# Number of employees:  192
# Industry : Jewelry stores
# Company description:  Jewelry Stores
# ####################################################################################################
# score:  6.666506
# Name:  Office Retail Limited
# Company id:  254631306
# Country:  United Kingdom
# Revenue:  1.6462254043084215
# Number of employees:  95
# Industry : Shoe stores
# Company description:  Shoe Stores
# ####################################################################################################
# score:  6.666506
# Name:  Aldo Denmark Aps
# Company id:  316027767
# Country:  Denmark
# Revenue:  0.8732712280348467
# Number of employees:  75
# Industry : Shoe stores
# Company description:  Shoe Stores
# ####################################################################################################
# score:  6.666506
# Name:  Boklageret As
# Company id:  281038942
# Country:  Norway
# Revenue:  4.205175070204886
# Number of employees:  71
# Industry : Book stores
# Company description:  Book Stores
# ####################################################################################################
# score:  6.666506
# Name:  Wilhelm Frick Buchhandlung Gesellschaft M.B.H.
# Company id:  217241518
# Country:  Austria
# Revenue:  3.128060823701044
# Number of employees:  65
# Industry : Book stores
# Company description:  Book Stores
# ####################################################################################################
# score:  6.666506
# Name:  Glitter ApS
# Company id:  109548259
# Country:  Denmark
# Revenue:  4.482972638703754
# Number of employees:  150
# Industry : Jewelry stores
# Company description:  Jewelry Stores
# ####################################################################################################
# score:  6.664047
# Name:  Basca - ComErcio De Objectos De DecoraCAo, Lda
# Company id:  183171872
# Country:  Portugal
# Revenue:  3.834124116260801
# Number of employees:  83
# Industry : Furniture stores
# Company description:  Furniture Stores
# ####################################################################################################
# score:  6.664047
# Name:  Due Mari Srl
# Company id:  308979719
# Country:  Italy
# Revenue:  1.7461564358657842
# Number of employees:  119
# Industry : Variety stores
# Company description:  Variety Stores
# ####################################################################################################
# score:  6.664047
# Name:  Appleby Jewellers Limited
# Company id:  146242953
# Country:  Ireland
# Revenue:  3.7137380765346197
# Number of employees:  59
# Industry : Jewelry stores
# Company description:  Jewelry Stores
# ####################################################################################################
# score:  6.663927
# Name:  Aktieselskabet Rdk
# Company id:  223215881
# Country:  Denmark
# Revenue:  3.97502964253136
# Number of employees:  150
# Industry : Jewelry stores
# Company description:  Jewelry Stores
# ####################################################################################################
# score:  6.663927
# Name:  Csm Holding As
# Company id:  246385039
# Country:  Norway
# Revenue:  0.0416751815683186
# Number of employees:  70
# Industry : Department stores
# Company description:  Department Stores
# ####################################################################################################
# score:  6.663927
# Name:  Aktieselskabet Sam. Andersen
# Company id:  51477598
# Country:  Denmark
# Revenue:  3.7826725315548315
# Number of employees:  150
# Industry : Shoe stores
# Company description:  Shoe Stores
# ####################################################################################################
# score:  6.663927
# Name:  Autotech Varebors As
# Company id:  307769059
# Country:  Norway
# Revenue:  2.029225438622676
# Number of employees:  62
# Industry : Department stores
# Company description:  Department Stores
# ####################################################################################################
# score:  6.663927
# Name:  Pec Srl
# Company id:  247224871
# Country:  Italy
# Revenue:  1.6990236785994839
# Number of employees:  69
# Industry : Variety stores
# Company description:  Variety Stores
# ####################################################################################################
# score:  6.663927
# Name:  Danielsen Sko AS
# Company id:  593036203
# Country:  Norway
# Revenue:  4.9161789254462
# Number of employees:  57
# Industry : Shoe stores
# Company description:  Shoe Stores
# ####################################################################################################
# score:  6.663927
# Name:  Schuurman Groep B.V.
# Company id:  46540676
# Country:  Netherlands
# Revenue:  0.3850185164403546
# Number of employees:  289
# Industry : Shoe stores
# Company description:  Shoe Stores
# ####################################################################################################
# score:  6.663927
# Name:  Praxis Sociedad Comercializadora Sa
# Company id:  260915055
# Country:  Spain
# Revenue:  3.873799798002469
# Number of employees:  61
# Industry : Book stores
# Company description:  Book Stores
# ####################################################################################################
# score:  6.6602597
# Name:  Aveny Rodovre A/S
# Company id:  265854334
# Country:  Denmark
# Revenue:  4.168739264444441
# Number of employees:  75
# Industry : Jewelry stores
# Company description:  Jewelry Stores
# ####################################################################################################
# score:  6.6602597
# Name:  Il Torrente Srl
# Company id:  253003311
# Country:  Italy
# Revenue:  0.011222085063404781
# Number of employees:  79
# Industry : Variety stores
# Company description:  Variety Stores
# ####################################################################################################
# score:  6.6602597
# Name:  Food Distribution Srl
# Company id:  587012187
# Country:  Italy
# Revenue:  4.996072270227808
# Number of employees:  73
# Industry : Variety stores
# Company description:  Variety Stores
# ####################################################################################################
# score:  6.6602597
# Name:  Alexander
# Company id:  276501964
# Country:  France
# Revenue:  0.4902390304118505
# Number of employees:  64
# Industry : Jewelry stores
# Company description:  Jewelry Stores
# ####################################################################################################
# score:  6.6602597
# Name:  Steinberger Gesellschaft M.B.H.
# Company id:  235473201
# Country:  Austria
# Revenue:  4.888666816294467
# Number of employees:  94
# Industry : Department stores
# Company description:  Department Stores
# ####################################################################################################
# score:  6.5605164
# Name:  Lp Bogense Aps
# Company id:  256535829
# Country:  Denmark
# Revenue:  1.6619353830386112
# Number of employees:  75
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  N & F - ComErcio E DistribuiCAo Alimentar, Lda
# Company id:  254618567
# Country:  Portugal
# Revenue:  2.560913477724161
# Number of employees:  233
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Societe Alsacienne De Boucherie Charcuterie
# Company id:  304425825
# Country:  France
# Revenue:  1.5528223543934463
# Number of employees:  147
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Favorit Marked A/S
# Company id:  46960829
# Country:  Denmark
# Revenue:  2.5813422619092345
# Number of employees:  75
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Wika Supermarked Koge, Gymnasievej 29 A/S
# Company id:  51443548
# Country:  Denmark
# Revenue:  2.8870097335703733
# Number of employees:  75
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Extracare Retail Limited
# Company id:  206734376
# Country:  United Kingdom
# Revenue:  4.603323963546066
# Number of employees:  115
# Industry : Used merchandise stores
# Company description:  Used Merchandise Stores
# ####################################################################################################
# score:  6.5605164
# Name:  Garben Enterprises Limited
# Company id:  222535524
# Country:  United Kingdom
# Revenue:  4.2956436791751225
# Number of employees:  125
# Industry : Liquor stores
# Company description:  Liquor Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Meny Himmelev Aps
# Company id:  158499374
# Country:  Denmark
# Revenue:  2.2680105616076247
# Number of employees:  75
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Soberdis S.A.
# Company id:  46840346
# Country:  France
# Revenue:  3.1683828975423634
# Number of employees:  73
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Swords Alliance Limited
# Company id:  256362509
# Country:  Ireland
# Revenue:  2.865485355178993
# Number of employees:  72
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Coop Online Ab
# Company id:  223170140
# Country:  Sweden
# Revenue:  2.0715990554192047
# Number of employees:  100
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  B.V. Retail Too Limited
# Company id:  267134849
# Country:  Ireland
# Revenue:  2.53438222421726
# Number of employees:  59
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Lcs Retail Limited
# Company id:  5600098
# Country:  United Kingdom
# Revenue:  2.799591594922668
# Number of employees:  159
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Hadsund Brugsforening A.M.B.A
# Company id:  52713899
# Country:  Denmark
# Revenue:  2.9268336667022328
# Number of employees:  75
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  A/S Jorgen Andersen. Malov
# Company id:  46959332
# Country:  Denmark
# Revenue:  4.330589739852035
# Number of employees:  75
# Industry : Hardware stores
# Company description:  Hardware Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Boyne Valley Supermarkets Limited
# Company id:  60219997
# Country:  Ireland
# Revenue:  4.512812254516889
# Number of employees:  79
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5605164
# Name:  Distriled Centre
# Company id:  222743872
# Country:  Belgium
# Revenue:  2.699905734485468
# Number of employees:  65
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5518456
# Name:  Soro Detail A/S
# Company id:  52677393
# Country:  Denmark
# Revenue:  2.9197705540335632
# Number of employees:  75
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5518456
# Name:  Marie Curie Trading Limited
# Company id:  182116889
# Country:  United Kingdom
# Revenue:  4.6826692549128355
# Number of employees:  3500
# Industry : Used merchandise stores
# Company description:  Used Merchandise Stores
# ####################################################################################################
# score:  6.5518456
# Name:  A. O'gorman & Company Limited
# Company id:  51701446
# Country:  Ireland
# Revenue:  2.8397014925373134
# Number of employees:  102
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5518456
# Name:  Sodix
# Company id:  46498713
# Country:  France
# Revenue:  4.735358545617776
# Number of employees:  100
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.549602
# Name:  Fast & Fresh (Restaurants) Ltd
# Company id:  111704756
# Country:  United Kingdom
# Revenue:  2.9029495922251773
# Number of employees:  389
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.549602
# Name:  Fabbrica Di Cioccolato Gay Odin Srl
# Company id:  581645716
# Country:  Italy
# Revenue:  4.984850185164404
# Number of employees:  62
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.549602
# Name:  Storbutiken I Lulea Ab
# Company id:  49756473
# Country:  Sweden
# Revenue:  0.01498329678956487
# Number of employees:  70
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.549602
# Name:  Skudenes Mat As
# Company id:  223759790
# Country:  Norway
# Revenue:  2.102243112114275
# Number of employees:  81
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.549602
# Name:  Somarvrac
# Company id:  146030411
# Country:  France
# Revenue:  2.318938390753002
# Number of employees:  65
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.549602
# Name:  Bollenedis
# Company id:  301209318
# Country:  France
# Revenue:  4.5426562675345075
# Number of employees:  266
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.549602
# Name:  Hornsherred Brugsforening
# Company id:  50309518
# Country:  Denmark
# Revenue:  3.965862623961385
# Number of employees:  150
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5495367
# Name:  Chiltern Stores Limited
# Company id:  381435600
# Country:  United Kingdom
# Revenue:  2.0286211286602045
# Number of employees:  90
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5495367
# Name:  Damberg Holding
# Company id:  224422894
# Country:  France
# Revenue:  0.004823252160251375
# Number of employees:  100
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5495367
# Name:  Michael Connolly And Sons Limited
# Company id:  126982727
# Country:  Ireland
# Revenue:  2.0196027381887554
# Number of employees:  60
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5495367
# Name:  Kerteminde Brugsforening
# Company id:  51327171
# Country:  Denmark
# Revenue:  4.138382907868458
# Number of employees:  150
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5495367
# Name:  Vonsild Brugsforening A.M.B.A.
# Company id:  61940418
# Country:  Denmark
# Revenue:  1.916808555082511
# Number of employees:  75
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5495367
# Name:  Alleens Supermarked A/S
# Company id:  46958415
# Country:  Denmark
# Revenue:  4.961460952257867
# Number of employees:  150
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5495367
# Name:  Spawell Auto Stop (Templeogue) Limited
# Company id:  598041391
# Country:  Ireland
# Revenue:  2.522324093816631
# Number of employees:  93
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5459633
# Name:  Coop Vikesa Sa
# Company id:  116244612
# Country:  Norway
# Revenue:  1.8743499016098333
# Number of employees:  61
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5459633
# Name:  Lundvalls Livs Ab
# Company id:  51181091
# Country:  Sweden
# Revenue:  0.004748227855848022
# Number of employees:  155
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5459633
# Name:  Myton Hospice (Promotions) Limited
# Company id:  276502744
# Country:  United Kingdom
# Revenue:  4.721005130273657
# Number of employees:  70
# Industry : Used merchandise stores
# Company description:  Used Merchandise Stores
# ####################################################################################################
# score:  6.5459633
# Name:  Aquatel
# Company id:  52171138
# Country:  France
# Revenue:  1.1920222197284256
# Number of employees:  64
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5459633
# Name:  Vinderup Og Omegns Brugsforening
# Company id:  312386153
# Country:  Denmark
# Revenue:  1.4855078453148272
# Number of employees:  75
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5459633
# Name:  Galtaback Holding Ab
# Company id:  116404725
# Country:  Sweden
# Revenue:  0.002215839666062411
# Number of employees:  81
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5459633
# Name:  Neuilly La Pointe
# Company id:  112942113
# Country:  France
# Revenue:  2.2528694871507127
# Number of employees:  100
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5459633
# Name:  Superbrugsen I SkArbAk Og Dagli'brugsen PA ROmO
# Company id:  62634120
# Country:  Denmark
# Revenue:  1.7907244799971147
# Number of employees:  75
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5459633
# Name:  Superbrugsen Kjellerup
# Company id:  127075606
# Country:  Denmark
# Revenue:  2.261097727931906
# Number of employees:  75
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5459633
# Name:  Bob Dis
# Company id:  23021694
# Country:  France
# Revenue:  0.002696667040736169
# Number of employees:  185
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.5459633
# Name:  SolAlven Ab
# Company id:  318120923
# Country:  Sweden
# Revenue:  0.9393049860613132
# Number of employees:  78
# Industry : Grocery stores
# Company description:  Grocery Stores, Nsk
# ####################################################################################################
# score:  6.450084
# Name:  Purplepigment, Unipessoal, Lda
# Company id:  586270385
# Country:  Portugal
# Revenue:  4.910965099315453
# Number of employees:  58
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.450084
# Name:  Dk Company Retail A/S
# Company id:  222661873
# Country:  Denmark
# Revenue:  4.932757664604338
# Number of employees:  150
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.450084
# Name:  Ligursarda Srl
# Company id:  182283887
# Country:  Italy
# Revenue:  4.477611940298508
# Number of employees:  62
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.450084
# Name:  Blm Srl
# Company id:  184178435
# Country:  Italy
# Revenue:  3.086073392436315
# Number of employees:  220
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.450084
# Name:  Masai Clothing Retail Norge As
# Company id:  611927995
# Country:  Norway
# Revenue:  4.993674097783983
# Number of employees:  87
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.4417415
# Name:  Street Wear Sverige AB
# Company id:  576226943
# Country:  Sweden
# Revenue:  4.3510649747499786
# Number of employees:  80
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.4417415
# Name:  Traktoren As
# Company id:  223401747
# Country:  Norway
# Revenue:  4.34099253520577
# Number of employees:  125
# Industry : Miscellaneous home furnishings stores
# Company description:  Miscellaneous Homefurnishings Stores, Nsk
# ####################################################################################################
# score:  6.4417415
# Name:  Little Smets Sarl
# Company id:  308965307
# Country:  Luxembourg
# Revenue:  0.3068230277185501
# Number of employees:  65
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.4417415
# Name:  Firetrap Limited
# Company id:  240622626
# Country:  United Kingdom
# Revenue:  3.658332598036126
# Number of employees:  60
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.4417415
# Name:  Ceblanal SL
# Company id:  216592807
# Country:  Spain
# Revenue:  4.403951296150825
# Number of employees:  75
# Industry : Miscellaneous home furnishings stores
# Company description:  Miscellaneous Homefurnishings Stores, Nsk
# ####################################################################################################
# score:  6.4417415
# Name:  Ralph Lauren Ireland Limited
# Company id:  133989799
# Country:  Ireland
# Revenue:  3.622159129166199
# Number of employees:  79
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.4417415
# Name:  Shades Collection Sl
# Company id:  289125287
# Country:  Spain
# Revenue:  4.327426775894962
# Number of employees:  77
# Industry : Miscellaneous home furnishings stores
# Company description:  Miscellaneous Homefurnishings Stores, Nsk
# ####################################################################################################
# score:  6.4417415
# Name:  Lester Bowden (1898) Limited
# Company id:  112206345
# Country:  United Kingdom
# Revenue:  4.177488560876307
# Number of employees:  106
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.4417415
# Name:  Petmania Limited
# Company id:  234059801
# Country:  Ireland
# Revenue:  4.850628436763551
# Number of employees:  200
# Industry : Miscellaneous home furnishings stores
# Company description:  Miscellaneous Homefurnishings Stores, Nsk
# ####################################################################################################
# score:  6.4417415
# Name:  Beckvalley Limited
# Company id:  267134751
# Country:  Ireland
# Revenue:  2.1206059925934237
# Number of employees:  59
# Industry : Miscellaneous home furnishings stores
# Company description:  Miscellaneous Homefurnishings Stores, Nsk
# ####################################################################################################
# score:  6.4417415
# Name:  Telyman Telecom Sl
# Company id:  82332707
# Country:  Spain
# Revenue:  4.740462349904612
# Number of employees:  75
# Industry : Miscellaneous home furnishings stores
# Company description:  Miscellaneous Homefurnishings Stores, Nsk
# ####################################################################################################
# score:  6.439698
# Name:  Adelsberger Textilhaus Gmbh
# Company id:  248551520
# Country:  Austria
# Revenue:  4.7037638873302665
# Number of employees:  91
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.439698
# Name:  Sir Price Gronland As
# Company id:  223426656
# Country:  Norway
# Revenue:  4.970597757576732
# Number of employees:  89
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.439698
# Name:  Pershus AS
# Company id:  223197053
# Country:  Norway
# Revenue:  3.9972583930141834
# Number of employees:  68
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.439698
# Name:  A.G. Clothing Limited
# Company id:  5495608
# Country:  United Kingdom
# Revenue:  3.799175626788348
# Number of employees:  6735
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.439698
# Name:  Pedersen Holding AS
# Company id:  222981306
# Country:  Norway
# Revenue:  4.460048081449148
# Number of employees:  61
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.439698
# Name:  Bogerud Tekstil Vest As
# Company id:  230443602
# Country:  Norway
# Revenue:  4.758433196865292
# Number of employees:  71
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.439681
# Name:  Butler - Richard I/S
# Company id:  51541651
# Country:  Denmark
# Revenue:  1.750750267872305
# Number of employees:  75
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.439681
# Name:  Origem TExtil, Lda
# Company id:  172601328
# Country:  Portugal
# Revenue:  2.584559533161261
# Number of employees:  62
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.439681
# Name:  Gina Tricot A/S
# Company id:  231030269
# Country:  Denmark
# Revenue:  4.613264525591761
# Number of employees:  150
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.439681
# Name:  Intersac - ComErcio De VestuArio, S.A.
# Company id:  183801905
# Country:  Portugal
# Revenue:  4.521629446751207
# Number of employees:  57
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.4361973
# Name:  Xmd Deutschland Gmbh
# Company id:  30446151
# Country:  Germany
# Revenue:  4.022487936258557
# Number of employees:  86
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.4361973
# Name:  Sunkost Butikk As
# Company id:  252162330
# Country:  Norway
# Revenue:  2.9497532783328095
# Number of employees:  76
# Industry : Miscellaneous food stores
# Company description:  Miscellaneous Food Stores, Nsk
# ####################################################################################################
# score:  6.4361973
# Name:  Helsemin A/s
# Company id:  223215786
# Country:  Denmark
# Revenue:  2.6600884542152508
# Number of employees:  150
# Industry : Miscellaneous food stores
# Company description:  Miscellaneous Food Stores, Nsk
# ####################################################################################################
# score:  6.4361973
# Name:  Veiga Vilarino S.L.
# Company id:  215999327
# Country:  Spain
# Revenue:  4.20644596566042
# Number of employees:  70
# Industry : Family clothing stores
# Company description:  Family Clothing Stores, Nsk
# ####################################################################################################
# score:  6.3439593
# Name:  Save
# Company id:  574346152
# Country:  France
# Revenue:  1.9542037930647513
# Number of employees:  322
# Industry : Computer and software stores
# Company description:  Computer And Software Stores, Nsk
# ####################################################################################################
