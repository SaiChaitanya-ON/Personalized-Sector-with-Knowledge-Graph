# %% [markdown]
# # Using Spark from Local

# %%
# !conda install -c conda-forge -y pyspark==2.4.3

# %%
def get_aws_credentials():
    """
        Loads AWS credentials from credentials file and sets env variables
    """
    credentials_file = os.getenv("HOME") + '/.aws/credentials'

    try:
        with open(credentials_file, 'r') as f:
            lines = f.read()
        config = dict([tuple([kv.strip() for kv in line.split('=')]) for line in lines.split('\n') if '=' in line])
    except FileNotFoundError:
        config = dict()
    if "aws_access_key_id" in config and "aws_secret_access_key" in config:
        return config["aws_access_key_id"], config["aws_secret_access_key"]
    elif "AWS_ACCESS_KEY_ID" in os.environ and "AWS_SECRET_ACCESS_KEY" in os.environ:
        return os.environ["AWS_ACCESS_KEY_ID"], os.environ["AWS_SECRET_ACCESS_KEY"]
    return None, None

# %%
import os
from pyspark.sql import SparkSession

# Set Spark Home
os.environ["SPARK_HOME"] = "/Users/hakan.ilter/dev/spark-2.4.3-bin-hadoop2.7"

# Get AWS credentials
aws_access_key_id, aws_secret_access_key = get_aws_credentials()

# Create Spark Session
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("SparkTest") \
    .config("spark.sql.warehouse.dir", "/tmp/spark-warehouse") \
    .config("spark.hadoop.fs.AbstractFileSystem.s3.impl", "org.apache.hadoop.fs.s3a.S3A") \
    .config("spark.hadoop.fs.AbstractFileSystem.s3a.impl", "org.apache.hadoop.fs.s3a.S3A") \
    .config("spark.hadoop.fs.s3.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
    .config("spark.driver.memory", "2g") \
    .config("spark.hadoop.fs.s3.access.key", aws_access_key_id) \
    .config("spark.hadoop.fs.s3.secret.key", aws_secret_access_key) \
    .config("spark.hadoop.fs.s3a.access.key", aws_access_key_id) \
    .config("spark.hadoop.fs.s3a.secret.key", aws_secret_access_key) \
    .getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://172-1-11-10.lightspeed.lbcktx.sbcglobal.net:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SparkTest</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.json("s3://ai-data-lake-dev-eu-west-1/staging/datafox/company/t=1563188581")
df.createOrReplaceTempView("datafox")
df.printSchema()
# Out:
# root
#  |-- icon_url: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- last_modified_date: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- object_type: string (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- url: string (nullable = true)

# %%
import pandas as pd

pdf = spark.sql("SELECT name, url FROM datafox").toPandas()
pdf
# Out:
#                                                    name  \
# 0     Society of Payment Security Professionals (SPS...
# 1                                         ASP Media Ltd
# 2                              Refrigerated Transporter
# 3                                             WCN Group
# 4                              Woodman Asset Management
# 5                               YourOnlineTVchannel.com
# 6                                         Kumatech Inc.
# 7                                                  CASE
# 8                                                Ravica
# 9                                    IT Structures Ltd.
# 10                                            Momentous
# 11                                              Say Ah!
# 12                               Larry Bodine Marketing
# 13                                  Flo-2d Software Inc
# 14                    Cintas Document Management UK Ltd
# 15                           Genroe (Australia) Pty Ltd
# 16                                          Inf Service
# 17                             Davarcci Associates Inc.
# 18                                           H2Glenfern
# 19                              The Presentation Factor
# 20                          Small School Districts Assn
# 21           Early Learning Coalition of Broward County
# 22                                    Arrow Media Group
# 23                                     Alava Ingenieros
# 24                                Freestyle Interactive
# 25                            Pine Financial Group, Inc
# 26                                    City of Rochester
# 27                                        AAF Cleveland
# 28                                     Sol Distribution
# 29                          Marion G Vedder Elem School
# ...                                                 ...
# 9970                   Jiangsu Yoke Technology Co., Ltd
# 9971           Jiangsu Protruly Technology Group Co Ltd
# 9972                                     SUNGWOO HITECH
# 9973                                         Macrofocus
# 9974                                           TalentXS
# 9975                       Taisol Electronics Co., Ltd.
# 9976                               TA Enterprise Berhad
# 9977                                             eTrove
# 9978                                       Seligdar PAO
# 9979                                          Liveminds
# 9980                           Seojin Automotive Co Ltd
# 9981                                         MailEnable
# 9982                                    Radiocentro C.A
# 9983                       Oak Hill Presbyterian Church
# 9984                                        FlexiFundIt
# 9985                                              Prezi
# 9986                          Jih Lin Technology Co Ltd
# 9987                      Jiangsu Yueda Group Co., Ltd.
# 9988                     Jl Stormwater Consultants Inc.
# 9989                    Jiangxi Selon Industrial Co Ltd
# 9990                                JPN Holdings Co Ltd
# 9991                     AimGlobal Technologies Company
# 9992                           Catapult Growth Partners
# 9993            Coventry Public Schools of Rhode Island
# 9994                                        JHC Systems
# 9995                                    harboranalytics
# 9996                                            Giotech
# 9997  Hospital Universitari Dexeus (Institut Univers...
# 9998                Josapar Joaquim Oliveira S.A. Part.
# 9999                         SVI Public Company Limited
#
#                                       url
# 0                 paymentsecuritypros.com
# 1                         aspmedialtd.com
# 2             refrigeratedtransporter.com
# 3                            wcngroup.com
# 4                              woodman.ch
# 5                 youronlinetvchannel.com
# 6                             kumatech.ca
# 7                             casebio.com
# 8                              ravica.com
# 9                        itstructures.com
# 10                        momentousuk.com
# 11                             say-ah.org
# 12                        larrybodine.com
# 13                             flo-2d.com
# 14                           cintas.co.uk
# 15                             genroe.com
# 16                      infservice.com.br
# 17                           davarcci.com
# 18                         h2glenfern.com
# 19                 presentationfactor.com
# 20                               ssda.org
# 21                         elcbroward.org
# 22          arrowmediagroup.wordpress.com
# 23                           alava-ing.es
# 24               freestyleinteractive.com
# 25                 pinefinancialgroup.com
# 26                    www.rochestermn.gov
# 27                       aafcleveland.com
# 28                 sol-distribution.co.uk
# 29                northbabylonschools.net
# ...                                   ...
# 9970                         yokechem.com
# 9971                      protruly.com.cn
# 9972                 english.swhitech.com
# 9973                       macrofocus.com
# 9974                         talentxs.com
# 9975                        taisol.com.tw
# 9976                            ta.com.my
# 9977                        www.etrove.ca
# 9978                          seligdar.ru
# 9979                        liveminds.com
# 9980                   secoautomotive.com
# 9981                       mailenable.com
# 9982                      radiocentro.com
# 9983                     oakhillpcusa.org
# 9984               www.flexifundit.com.au
# 9985                           iprezi.com
# 9986                        jihlin.com.tw
# 9987                        www.yueda.com
# 9988                     jlstormwater.com
# 9989                       chinaselon.com
# 9990                         jpn-gr.co.jp
# 9991                    aimglobaltech.com
# 9992                   catapultgrowth.com
# 9993                  coventryschools.net
# 9994                        jhc.financial
# 9995                  harboranalytics.com
# 9996                        giotech.co.uk
# 9997  www.quironsalud.es/dexeus-barcelona
# 9998                       josapar.com.br
# 9999                            svi.co.th
#
# [10000 rows x 2 columns]

# %%
pdf.to_csv("/tmp/company-urls.csv", index=False, sep="\t")
