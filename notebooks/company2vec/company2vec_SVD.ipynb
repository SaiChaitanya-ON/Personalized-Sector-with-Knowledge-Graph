// %%
%%configure -f
{"driverMemory": "47696M", 
 "executorCores": 4,
 "executorMemory": "47696M",
 "conf": {"spark.default.parallelism": 1000,
          "spark.driver.maxResultSize": "23848M",
          "spark.sql.shuffle.partitions": 1000
         }
}
// Out:
// Current session configs: <tt>{'driverMemory': '47696M', 'executorCores': 4, 'executorMemory': '47696M', 'conf': {'spark.default.parallelism': 1000, 'spark.driver.maxResultSize': '23848M', 'spark.sql.shuffle.partitions': 1000}, 'kind': 'pyspark'}</tt><br>
// No active sessions.

// %%
model_path = "s3://onai-ml-dev-eu-west-1/company2vec/model/svd"
word2id_path = "s3://onai-ml-dev-eu-west-1/company2vec/common"
data_path = "s3://onai-ml-dev-eu-west-1/company2vec/data"
// Out:
// Starting Spark application
// <table>
// <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>14</td><td>application_1566985851061_0015</td><td>pyspark</td><td>idle</td><td></td><td></td><td>✔</td></tr></table>
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// SparkSession available as 'spark'.
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
from gensim.utils import tokenize
from langdetect import detect
import string
from itertools import islice
import numpy as np
from scipy.sparse import csr_matrix
import smart_open
import scipy

from pyspark.sql import SparkSession
import pyspark.sql.functions as F
import pyspark.sql.types as T

from pyspark.mllib.linalg import DenseMatrix
from pyspark.mllib.linalg.distributed import RowMatrix
from pyspark.mllib.linalg import Vector as MLLibVector, Vectors as MLLibVectors

from pyspark.ml.linalg import Vectors, VectorUDT

import pickle
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %% [markdown]
// ### Train a Truncated SVD on the (sparse) company feature matrix

// %%
companies_data = spark.read.load("s3://ai-data-lake-dev-eu-west-1/business/capiq/company_denormalized")
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
dups = [row.company_id for row in 
         companies_data
         .groupBy("company_id")
         .agg(F.count("*").alias("count"))
         .filter(F.col("count") > 1)
         .collect()
]
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
companies_data = companies_data.filter(~F.col("company_id").isin(dups))
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
max_desc = 1000
cap_description_udf = F.udf(lambda desc: desc[:max_desc])
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
x_joined = (spark.read.load(f"{data_path}/raw_company_features")
            .join(companies_data,
                  on = ["company_id"]
                 )
            .select("company_id",
                    cap_description_udf("company_name").alias("company_name"),
                    cap_description_udf("company_description").alias("company_description"),
                    "country",
                    "sic_code",
                    "latest_revenue",
                    "size",
                    "feature_indices",
                    "feature_values"
                   )
           )
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
x_joined.filter("company_id == '704634'").show(20, False)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// +----------+-------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+--------+------------------+-----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
// |company_id|company_name                               |company_description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |country|sic_code|latest_revenue    |size |feature_indices                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |feature_values                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
// +----------+-------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+--------+------------------+-----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
// |704634    |Bayerische Motoren Werke Aktiengesellschaft|Bayerische Motoren Werke Aktiengesellschaft, together with its subsidiaries, develops, manufactures, and sells automobiles and motorcycles, and spare parts and accessories worldwide. The company operates through Automotive, Motorcycles, and Financial Services segments. The Automotive segment develops, manufactures, assembles, and sells automobiles and off-road vehicles under the BMW, MINI, and Rolls-Royce brands; and spare parts and accessories, as well as offers mobility services. This segment sells its products through independent and authorized dealerships. The Motorcycles segment develops, manufactures, assembles, and sells motorcycles under the BMW Motorrad brand; and spare parts and accessories. The Financial Services segment is involved in automobile leasing, fleet and multi-brand business, retail and dealership financing, customer deposit business, and insurance activities. The company has a strategic collaboration with Jaguar Land Rover Automotive plc to develop electric drive|Germany|        |108166.88859298713|44014|[162, 171, 175, 181, 184, 331, 345, 397, 664, 911, 1128, 1357, 1679, 2071, 2096, 2407, 2414, 2416, 2728, 2761, 2776, 2777, 2780, 2781, 3391, 3411, 3490, 3645, 3796, 3834, 4436, 4678, 4820, 4824, 5008, 5394, 5395, 5443, 5841, 5859, 6448, 7142, 7346, 7589, 7776, 7809, 7874, 8126, 8167, 8232, 8256, 8412, 8516, 8522, 8834, 9217, 9373, 9497, 9609, 9610, 9834, 9851, 9977, 10134, 10138, 10142, 10148, 10294, 10627, 10994, 11311, 11694, 12140, 12153, 12214, 12273, 12698, 12742, 12878, 12954, 12993, 13069, 13334, 13496, 13529, 13597, 13602, 13612, 13699, 13818, 13980, 14188, 14961, 14973, 15113, 15114, 15117, 15832, 16969, 17714, 18274, 18302, 18350, 18352, 18422, 18782, 18815, 19014, 19101, 19455, 19760, 19861, 19912, 21046, 21201, 21291, 21329, 21654, 21761, 21973, 22557, 22623, 22831, 22834, 22908, 22955, 23574, 23633, 24138, 24152, 24325, 24351, 24707, 24713, 24714, 24716, 24904, 24993, 25394, 25829, 25908, 26071, 26451, 26568, 26660, 26851, 26925, 26967, 27310, 27318, 27591, 27727, 28103, 28431, 28470, 29049, 29077, 29509, 29551, 29583, 29712, 30034, 30342, 30465, 30472, 30541, 30708, 30758, 30831, 30922, 31634, 32249, 32381, 32723, 32776, 32900, 33064, 33083, 33084, 33328, 33408, 33761, 34034, 34132, 34149, 34176, 34252, 34382, 34409, 34410, 34436, 34521, 34584, 35159, 35572, 35600, 35643, 35778, 35803, 36563, 36596, 36765, 36766, 37038, 37351, 37613, 37766, 37868, 38107, 38184, 38258, 38968, 39588, 40144, 40368, 40457, 40458, 40520, 40900, 41549, 41834, 42039, 42079, 42085, 42829, 42830, 42833, 43790, 43794, 43867]|[7.517977857914299, 4.551785284479301, 3.1067733565343776, 3.424729187093642, 7.203635094642752, 3.2633686783202585, 5.609192927905722, 2.7133759618416153, 6.950688877416045, 10.548402609529548, 4.1499731981435035, 2.915434753809799, 3.6757117852907366, 3.6085216739321195, 2.677971173086647, 6.064845572577374, 9.443713400715456, 3.931721307380859, 8.242689050436185, 7.1881795140759905, 8.991384426787294, 6.454874604757126, 6.224720842982998, 3.6618879371508575, 0.6002766506634519, 4.231491723877456, 13.24926780682433, 5.161857694012626, 9.265607640455908, 4.478667482259834, 24.58732889453424, 6.268315468671482, 3.603716022978931, 8.799334179499063, 4.566517978961446, 1.985941376780566, 4.507869777191161, 4.230298936059478, 6.90589888868642, 8.082334853360736, 4.178898464159909, 7.374629132197559, 6.215923454245508, 12.416391244197078, 4.458372492664758, 1.7065854619348815, 6.41935853288641, 3.3341357528999174, 4.930845834648854, 7.681835730632885, 2.992775667855537, 6.633389563165537, 4.490038444385296, 4.120709406999595, 3.4034659426246736, 4.494857661050747, 5.612049477813793, 2.61371144080775, 5.631835104557564, 7.10498429638266, 3.346140908870671, 5.7219335344199775, 5.44422941423157, 5.18121595077035, 4.269559800899549, 6.64249477694851, 3.259969002503184, 4.278999157486012, 5.477312458739094, 5.972891025009609, 6.20002488615383, 2.4656 ...
// +----------+-------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+--------+------------------+-----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

// %%
x_joined.write.parquet(f"{data_path}/company_features_joined", mode="overwrite")
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
x_joined = (
    spark.read.load(f"{data_path}/company_features_joined")
)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
x_joined.printSchema()
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// root
//  |-- company_id: integer (nullable = true)
//  |-- company_name: string (nullable = true)
//  |-- company_description: string (nullable = true)
//  |-- country: string (nullable = true)
//  |-- sic_code: string (nullable = true)
//  |-- latest_revenue: double (nullable = true)
//  |-- size: integer (nullable = true)
//  |-- feature_indices: array (nullable = true)
//  |    |-- element: integer (containsNull = true)
//  |-- feature_values: array (nullable = true)
//  |    |-- element: double (containsNull = true)

// %%
def zipped_data(x_rdd):
    ret = []
    n_rows = 0
    n_cols = None
    
    def generate_sparse_matrix(x_rdd):
        nonlocal n_cols
        nonlocal n_rows
        for i,el in enumerate(x_rdd.collect()):
            ret.append((el.company_id,
                        el.company_name,
                        el.company_description,
                        el.country,
                        el.sic_code,
                        el.latest_revenue
                       ))
            if n_cols is None:
                n_cols = el.size
            for j,v in zip(el.feature_indices, el.feature_values):
                yield (i,j,v)
            n_rows += 1

    row_ind, col_ind, data = zip(*generate_sparse_matrix(x_rdd))

    return ret, (n_rows, n_cols), (row_ind, col_ind, data)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
metadata, shape, (row_ind, col_ind, data) = zipped_data(x_joined)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
X = csr_matrix((data, (row_ind, col_ind)), shape=shape)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
X.shape
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// (3381364, 44014)

// %%
X_metadata = np.array([
    list(row) for row in metadata
])
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
with smart_open.open(f"{model_path}/X/company_info.np", "wb") as f:
    np.save(f, X_metadata)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
with smart_open.open(f"{model_path}/X/X.npz", "wb") as f:
    scipy.sparse.save_npz(f, X)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=200, n_iter=20, random_state=42)
svd.fit(X)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// TruncatedSVD(algorithm='randomized', n_components=200, n_iter=20,
//              random_state=42, tol=0.0)

// %%
V = svd.components_
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
V.shape
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// (200, 44014)

// %%
with smart_open.open(f"{model_path}/V/mat.np", "wb") as f:
    np.save(f, V, allow_pickle=False)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
with smart_open.open(f"{model_path}/truncated_svd.pkl", "wb") as f:
    pickle.dump(svd, f)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
with smart_open.open(f"{model_path}/truncated_svd.pkl", "rb") as f:
    svd = pickle.load(f)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
with smart_open.open(f"{model_path}/V/mat.np", "rb") as f:
    V = np.load(f)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %% [markdown]
// ### Now that we have SVD, project the data and write associated descriptions/metadata

// %%
X_pca = X.dot(V.T)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
company2id_ini = {}
for i,desc in enumerate(metadata):
    company2id_ini[desc[0]] = i
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
len(company2id_ini)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// 3381364

// %%
query_company = 291847304
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
company2id_ini[query_company]
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// 2048758

// %%
X_pca[X_metadata[:,0] == query_company]
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// array([[ 6.99342476e+00,  1.23361207e-01,  7.55503175e+00,
//         -1.47180055e+00, -1.66754650e-01, -4.78843013e-01,
//          1.27392257e-01,  3.82081615e-01,  1.49364915e+00,
//         -6.78287935e-01, -1.09563525e+00,  1.79687146e-02,
//         -1.93578629e+00, -6.28666184e-01, -4.77632849e-01,
//          2.21428934e+00,  1.75651998e+00,  1.35866353e+00,
//          1.50278603e+00, -6.95638706e-01,  1.35153342e-02,
//         -1.15403851e-01, -6.03382160e-01,  1.60183587e-01,
//          1.47578413e-01,  5.97508492e-01, -1.11147658e-02,
//         -6.06817081e-01,  1.16312617e+00, -2.51390059e-01,
//          1.57477443e-01, -1.18196771e+00,  1.09097164e+00,
//          3.30627755e+00,  6.91424056e-01, -2.11149030e+00,
//          5.91365602e-02, -8.14749769e-01, -7.79311408e-01,
//         -2.09223824e+00, -4.07138793e-01,  8.76569199e-01,
//         -6.35536759e-01, -2.72670741e-01,  1.53076927e+00,
//         -2.05945185e-01, -1.38593745e+00, -5.67628682e-01,
//          1.05902422e+00, -1.36174678e+00, -1.08607428e+00,
//         -2.17642557e+00,  7.48467803e-01,  6.51595307e-02,
//          4.41524487e-02, -7.77860519e-02, -4.29489414e-01,
//          4.52973859e-01, -8.22751519e-01,  4.21102181e-01,
//          1.61884259e+00, -2.05922664e+00, -8.58564090e-01,
//         -4.44207590e-01,  4.72635721e-01,  3.11137262e-01,
//          3.23682624e-01, -6.94866348e-02, -7.40686025e-01,
//         -1.23981861e+00,  3.30526270e-01, -1.08202787e+00,
//         -3.53586632e-01,  1.10951169e-01,  4.51034855e-01,
//          7.88502465e-01,  4.77270610e-01,  8.16622674e-01,
//         -4.65496996e-01,  4.29299480e-01,  7.30599725e-01,
//         -1.23154455e+00, -1.13587055e+00,  4.64061174e-01,
//          8.64602433e-02,  7.25397596e-01, -4.40883671e-02,
//          6.04512186e-01, -2.41248818e-01,  2.02800279e-02,
//         -7.38754246e-01,  1.58791580e+00,  2.80058524e-01,
//         -8.23128205e-01,  1.36617951e+00,  6.68478297e-01,
//         -6.74289073e-01,  7.29987430e-01, -2.61002290e-01,
//         -1.57461137e+00,  9.45547403e-01, -3.83556197e-01,
//         -7.12800295e-01,  1.72472527e-01, -1.62453158e+00,
//         -4.51187315e-01,  1.06116305e+00, -1.70096216e+00,
//          5.22333640e-02, -3.85180291e-03,  1.84813790e-01,
//          9.43105282e-02, -6.67829408e-01, -4.18411628e-01,
//         -3.96323776e-01,  1.03099590e-01, -1.48168899e+00,
//          3.38187683e-02,  9.96602986e-01, -1.68709236e+00,
//          2.68148937e-01, -7.18189335e-01, -1.05429527e-01,
//         -4.09138883e-01, -1.13720175e-01,  7.84258820e-02,
//         -4.25403594e-01, -4.79659494e-01,  7.16789301e-02,
//          1.61586102e+00, -1.24200331e+00, -6.31480717e-01,
//          1.48438713e+00, -1.32957179e+00,  6.53929129e-01,
//          2.82672015e-01, -1.24619118e-01,  7.78389406e-02,
//         -1.58117091e-01,  1.27260866e+00,  4.68206208e-01,
//         -1.05200750e-01, -7.03223284e-01, -2.89768759e-01,
//          4.13526416e-01,  9.92069316e-01,  3.50177174e-01,
//          3.54681610e-01,  3.69789021e-01,  3.17752110e-01,
//          1.35291171e+00,  1.33301085e+00, -1.89250514e-02,
//          1.98637539e-01, -5.01804344e-01, -4.28801391e-01,
//         -8.75001389e-01, -3.58177335e-01,  3.07061478e-01,
//          7.81492164e-01,  6.64911350e-01, -5.24558278e-01,
//          1.27919040e+00,  1.92003674e+00,  4.44051271e-02,
//         -5.21844140e-01, -4.75684960e-01, -3.71066778e-01,
//          5.96299971e-01,  1.40045551e+00,  1.06090249e+00,
//         -4.21498332e-01, -1.95713580e+00, -3.17227688e-01,
//         -2.88686583e-02,  2.10904620e-01,  8.15241250e-02,
//          1.43322555e-01,  6.14604145e-01,  4.39734421e-01,
//         -1.80641589e+00,  6.19496317e-01,  8.80810194e-01,
//          5.36624194e-01, -1.00924446e+00,  5.67147323e-01,
//          1.34304252e+00,  1.99088799e+00, -1.05231803e+00,
//          5.15318441e-01, -4.20329817e-02,  8.52063899e-01,
//          2.59348970e-01,  1.45337848e+00, -9.65392661e-01,
//          4.24635882e-01, -2.51010973e-01,  6.75286976e-01,
//         -1.27844423e+00, -5.36127483e-01]])

// %%
X_pca = X_pca.astype(np.float32)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
with smart_open.open(f"{model_path}/X/X_pca.np", "wb") as f:
    np.save(f, X_pca, allow_pickle=False)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

// %%
with smart_open.open(f"{model_path}/X/x_pca.np", "wb") as f:
    np.save(f, X_pca[:10000], allow_pickle=False)
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
