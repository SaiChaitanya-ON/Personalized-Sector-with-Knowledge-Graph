# %%
import pandas as pd
import string
import csv
import re
import gensim
from langdetect import detect
from gensim.utils import tokenize
import numpy as np
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer

pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

input_file = '../../data/urls_description.csv'
write_file = '../../data/urls_keywords.csv'
input_file = '/acornML/resources/files/web_crawler/urls_description.csv'
write_file = '/acornML/resources/files/web_crawler/urls_keywords.csv'

weird_char = '\xfe'


def process_text(text):
    words = tokenize(text, lower=True)
    return ' '.join(list(filter(lambda word: word not in string.punctuation and word.isalpha(), words)))


def check_language(text):
    try:
        return detect(text)
    except:
        return ''


def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)


def process_too_long_text(text):
    sent = list(gensim.summarization.textcleaner.get_sentences(text))
    idx = min(len(sent), 3)
    return ' '.join(sent[0:idx])


def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []

    for idx, score in sorted_items:
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    results = {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]] = score_vals[idx]

    return results


def extract_description_pattern_is(text, company_name):
    # Extract description following pattern: <Company name> is ...
    description = ''
    if company_name in text:
        idx = text.find(company_name)
        potential_text = text[idx:idx + len(company_name) + 30]
        if ' is ' in potential_text:
            end_idx = len(text)
            for sym in ['*', '#', '|', '>']:
                sym_idx = text.find(sym, idx)
                if sym_idx != -1:
                    end_idx = min(end_idx, sym_idx)

            extracted = text[idx:end_idx]
            sent = list(gensim.summarization.textcleaner.get_sentences(extracted))
            extracted_desc = sent[0]
            if extracted_desc.split(' ')[-1] in {'Inc.', 'U.S.'} and len(sent) > 1:
                extracted_desc += ' ' + sent[1]
            if len(extracted_desc.split()) > 5:
                description = extracted_desc.replace('\n', ' ')
    return description


def extract_description_pattern_who_we_are(text):
    # Extract description following pattern: Who we are, ...
    description = ''
    text = text.split('\n')
    for idx, line in enumerate(text):
        for marker in ['# who we are', '# overview', '# company overview', '# about', '# mission',
                       '# our mission']:
            if marker in line.lower():
                start_idx = idx + 1
                while start_idx < len(text):
                    if text[start_idx] == '':
                        start_idx += 1
                    else:
                        break

                end_idx = start_idx + 1
                while end_idx < len(text):
                    if text[end_idx] != '':
                        end_idx += 1
                    else:
                        break

                if start_idx < len(text):
                    extracted = ' '.join(text[start_idx:end_idx])
                    extracted_desc = process_too_long_text(extracted)

                    extracted_desc_splits = extracted_desc.split()
                    if len(extracted_desc_splits) > 5 and extracted_desc_splits[0][0] != '*':
                        if extracted_desc_splits[0][0] == '#':
                            extracted_desc = ' '.join(extracted_desc_splits[1:])
                        description = extracted_desc
                        break
    return description

def preprocess_df(df):
    df['text'] = df['text'].str.replace(weird_char, '\n')
    df['about_us_text'] = df['about_us_text'].str.replace(weird_char, '\n')
    df['description'] = df['description'].str.replace(weird_char, '\n')

    df['text_lang'] = df['text'].apply(lambda x: check_language(x))
    df['about_us_text_lang'] = df['text'].apply(lambda x: check_language(x))

    return df

# %%
df = pd.read_csv(input_file, sep='\t', quoting=csv.QUOTE_NONE).fillna('')
df = preprocess_df(df)

docs = []
for index, row in df.iterrows():
    for field, field_lang in {'text':'text_lang', 'about_us_text':'about_us_text_lang'}.items():
        if row[field] and row[field_lang] == 'en':
            docs.append(process_text(row[field]))

# remove words appearing in more than 95% / less than 1% of all documents
cv = CountVectorizer(max_df=0.95, min_df=0.01, stop_words=gensim.parsing.preprocessing.STOPWORDS)
word_count_vector = cv.fit_transform(docs)

tfidf_transformer = TfidfTransformer(smooth_idf=True, use_idf=True)
tfidf_transformer.fit(word_count_vector)

feature_names = cv.get_feature_names()

# %%
count_valid_description = 0
for index, row in df.iterrows():
    
    # check if the description from meta field is in English and has more than 3 tokens
    if check_language(row['description']) == 'en' and len(row['description'].split()) > 3:
        description = row['description']
        description = process_too_long_text(description)
        count_valid_description += 1
    else:
        description = ''

    keywords_text = []
    for field, field_lang in {'text':'text_lang', 'about_us_text':'about_us_text_lang'}.items():
        if row[field]:
            if row[field_lang] != 'en':
                continue

            keywords_text.append(row[field])

            if not description:
                description = extract_description_pattern_is(row[field], row['name'])
                if not description:
                    description = extract_description_pattern_who_we_are(row[field])

    df.loc[index, 'description'] = description
    
    keywords_text = ' '.join(keywords_text)
    
    # Check if the website text + about us page text has more than 50 tokens
    if len(keywords_text.split()) > 50:
        keywords_text += ' ' + description
        tf_idf_vector = tfidf_transformer.transform(cv.transform([keywords_text]))
        sorted_items = sort_coo(tf_idf_vector.tocoo())
        keywords = extract_topn_from_vector(feature_names, sorted_items, 10)
    else:
        keywords = {}

    df.loc[index, 'keywords'] = ', '.join(['%s: %s' % (k, v) for (k, v) in keywords.items()]) #' '.join(keywords)

# %%
print(count_valid_description)
print(df[df['description']!=''].shape)
print(df[df['keywords']!=''].shape)
# Out:
# 2574
# (3699, 10)
# (5306, 10)

# %%
df[(df['description']!='')&(df['keywords']!='')][['name','url','description','keywords']]
# Out:
#                                                                                      name  \
# 5     Walton & Post Inc
# 8     Rice Software Consulting L L C
# 12    Health Officers Association of California
# 17    Management Consultants
# 33    BEST Robotics Inc.
# 43    Davarcci Associates Inc.
# 48    Central Carolina Skating Club, Inc.
# 51    Winning Work
# 52    QuickFlows
# 55    Capital City Media
# 56    Adam Continuity
# 60    Pathologyoutlines Com Inc
# 62    Examzone
# 67    Say Ah!
# 68    AIM Publications
# 70    Fashion With Flair by Lori Wynne
# 72    corner stone
# 76    blog: Copyright or Wrong. Coultertm.com
# 79    Gimbal Canada Inc.
# 80    AAF Cleveland
# 83    PresentationXpert
# 87    EMERGING TECHNOLOGIES ASSOCIATES, INC.
# 89    Vizual Business Tools
# 90    Marketing Artfully
# 91    Arrow Media Group
# 99    Institute for Information Infrastructure Protection (I3P)
# 100   Wellness Workdays
# 101   Barclays Global Investors Limited
# 103   Early Learning Coalition of Broward County
# 105   AMT Futures Limited
# 106   Harwood Capital LLP
# 108   PHS Chiropractic
# 111   RadTech International
# 112   Ontario Good Roads Association
# 113   Business Career College
# 116   Navotron
# 119   RECYCLEFLORIDA TODAY, INCORPORATED
# 121   Walker
# 122   ILLINOIS MEDICAL EMERGENCY RESPONSE TEAM
# 123   Larrabee Co
# 124   Paul Gillin Communications
# 126   Limestone Learning
# 127   Act Missouri
# 128   Beckett Asset Management
# 129   Mitra Marketing
# 130   Court House Clincs
# 131   Madera Group
# 132   UK Skills
# 133   Jackpine Technologies Corporation
# 135   Paychex Insurance Agency, Inc.
# 139   ACT-AD Coalition
# 143   Association for Radiologic and Imaging Nursing (ARIN)
# 9928  ESM Technologies
# 9930  The Concept Studio
# 9932  Douglas Lighting Controls
# 9935  Com Microfilm Company
# 9936  Starland Holdings Ltd
# 9938  Rowell Payroll Company LLC
# 9942  ContraVest Builders
# 9944  American Fisheries Society
# 9946  Kansas Traffic Safety Resource Office
# 9948  MUUSJA - Minnesota Unitarian Universalist Social Justice Alliance
# 9953  Noah Data Technologies Inc.
# 9954  Macrofocus
# 9955  Aggregated Micro Power Holdings PLC
# 9956  Y2FOX
# 9957  NGNA, INC.
# 9959  New York State Association of Community & Residential Agencies
# 9960  eTrove
# 9962  Missouri-ag Inds Council Inc
# 9964  ImageFast
# 9965  BestColleges.com
# 9966  Custom Goods
# 9968  PureBase Corp
# 9969  World Technology Corp.
# 9971  MyBump
# 9972  DogBizPro
# 9974  Solusi Tunas Pratama Tbk PT
# 9976  National Certification Board for Therapeutic Massage & Bodywork aka NCBTMB
# 9977  Oak Hill Presbyterian Church
# 9978  Journey
# 9979  The Association of Plastic Recyclers
# 9980  Stride Property Ltd
# 9981  FlexiFundIt
# 9984  Merge IT
# 9991  beTravelwise
#
#                                               url  \
# 5     www.waltonpost.com
# 8     ricesoftware.com
# 12    calhealthofficers.org
# 17    managementconsultants.com
# 33    bestinc.org
# 43    davarcci.com
# 48    centralcarolinasc.com
# 51    winningwork.com
# 52    quickflows.com
# 55    capitalcitymedia.co.uk
# 56    adam.co.uk
# 60    pathologyoutlines.com
# 62    examzone.com
# 67    say-ah.org
# 68    aimpublications.com
# 70    fashionwithflair.com
# 72    cornerstonesolutiononline.com
# 76    coultertm.com
# 79    gimbalcanada.com
# 80    aafcleveland.com
# 83    presentationxpert.com
# 87    emergingtechnologiesassociates.com
# 89    vizualms.co.uk
# ...
# 9752  trial: 0.458, tools: 0.228, pricing: 0.225, register: 0.177, free: 0.17, loan: 0.162, tool: 0.159, integrations: 0.159, start: 0.153, client: 0.151
# 9753  committee: 0.286, national: 0.284, officers: 0.244, recommendations: 0.229, control: 0.188, annual: 0.175, personnel: 0.172, meeting: 0.164, committees: 0.158, updated: 0.15
# 9759  scope: 0.435, windows: 0.341, nc: 0.276, immediate: 0.164, repair: 0.162, provide: 0.153, processing: 0.142, support: 0.136, customers: 0.129, goal: 0.125
# 9761  cloud: 0.327, legal: 0.291, services: 0.235, desktop: 0.212, sector: 0.195, sectors: 0.188, cyber: 0.169, uk: 0.153, infrastructure: 0.15, managed: 0.147
# 9762  death: 0.721, presentation: 0.323, presentations: 0.207, design: 0.162, title: 0.149, themes: 0.146, workshop: 0.13, seminar: 0.118, training: 0.117, skills: 0.114
# 9764  bright: 0.383, jul: 0.356, children: 0.303, search: 0.245, events: 0.188, solutions: 0.176, family: 0.168, news: 0.154, sorry: 0.154, dec: 0.149
# 9767  customer: 0.406, retention: 0.316, customers: 0.255, lose: 0.213, demo: 0.207, loss: 0.18, purchases: 0.18, machine: 0.171, sales: 0.17, insights: 0.166
# 9768  stone: 0.369, collection: 0.305, wood: 0.253, announcements: 0.201, classic: 0.194, enquiries: 0.191, promotions: 0.184, effect: 0.141, app: 0.139, beauty: 0.139
